# %% [markdown]
# # Notebook 02: QLoRA Fine-tuning
# Documentation link to the Colab notebook used for A100 training.

# %%
print("The full QLoRA fine-tuning code is located in: Copy_of_Untitled0.ipynb")
print("Or you can run the local script: python finetuning/train_qlora.py")
