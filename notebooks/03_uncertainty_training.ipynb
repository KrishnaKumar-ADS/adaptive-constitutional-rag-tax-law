# %% [markdown]
# # Notebook 03: Uncertainty Training
# Trains the Gradient Boosting Classifier for uncertainty quantification.

# %%
print("See src/uncertainty/train_model.py for the full training loop.")
