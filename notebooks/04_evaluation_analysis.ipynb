# %% [markdown]
# # Notebook 04: Evaluation Analysis
# Run this after benchmark/run_evaluation.py to analyze results.

# %%
import pandas as pd
import matplotlib.pyplot as plt

try:
    df = pd.read_csv('../benchmark/reports/final_eval_report.csv')
    display(df)
    
    df.plot(x='Baseline', y=['Hallucination Rate (%)', 'Legal Groundedness (LGS)'], kind='bar')
    plt.title('Baseline Comparison')
    plt.show()
except FileNotFoundError:
    print("Run python -m benchmark.run_evaluation first!")
